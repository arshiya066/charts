# %%
include c:\toolkit\subroutines\workfile.prg 

pageselect daily
get us_ms_sp_d wd_ms_sp$_d 

series us_ms_relsp = us_ms_sp_d / wd_ms_sp$_d 

smpl 2011 {enddate}
call lmaster("p1","us_ms_relsp","minmax","mrbrg1b","","")
p1.addtext(0.5,-0.14) "U.S.: Relative Stock Price*"
p1.addtext(0, 3.25) "* Source: MSCI"

show p1
